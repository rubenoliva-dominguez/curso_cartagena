# %% [markdown]
# <a href="https://colab.research.google.com/github/rubenoliva-dominguez/curso_cartagena/blob/main/dia4-2/0_ollama.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ollama and Gemini API

# %% [markdown]
# ## Ollama local

# %%
import ollama

response = ollama.chat(
    model="hdnh2006/salamandra-2b-instruct:latest",
    messages=[
        {"role": "system", "content": "Eres un asistente maravilloso de programación."},
        {"role": "user", "content": "Escribe una función en Python para búsqueda binaria para un array ordenado."}
    ],
    options={
        "temperature": 0.3
    }
)

print(response["message"]["content"])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_164/1803357406.py in <cell line: 0>()
# ----> 1 import ollama
#       2
#       3 response = ollama.chat(
#       4     model="hdnh2006/salamandra-2b-instruct:latest",
#       5     messages=[
#
# ModuleNotFoundError: No module named 'ollama'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ## Ollama cloud

# %%
# !pip install ollama
from ollama import Client

API_KEY = "64596f8798a148c1a6d230810171b445.9O8NWylmgIsOA98Ajsf6Qry5"

client = Client(
    host="https://ollama.com",
    headers={'Authorization': 'Bearer ' + API_KEY}
)

messages = [
  {"role": "system", "content": "Eres un asistente maravilloso de programación."},
  {"role": "user", "content": "Escribe una función en Python para búsqueda binaria para un array ordenado."},
]

response = client.chat('ministral-3:14b-cloud', messages=messages, options={"temperature": 0.3})
print(response['message']['content'])
# Out:
# Collecting ollama
#   Downloading ollama-0.6.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: httpx>=0.27 in /usr/local/lib/python3.12/dist-packages (from ollama) (0.28.1)
# Requirement already satisfied: pydantic>=2.9 in /usr/local/lib/python3.12/dist-packages (from ollama) (2.12.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27->ollama) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27->ollama) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27->ollama) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27->ollama) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.27->ollama) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9->ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9->ollama) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9->ollama) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9->ollama) (0.4.2)
# Downloading ollama-0.6.1-py3-none-any.whl (14 kB)
# Installing collected packages: ollama
# Successfully installed ollama-0.6.1
# ¡Claro! Aquí tienes una implementación clásica de la **búsqueda binaria** en Python para un array ordenado. La búsqueda binaria tiene una complejidad de tiempo de **O(log n)**, lo que la hace muy eficiente para listas grandes.
#
# ### Función de búsqueda binaria:
# ```python
# def busqueda_binaria(arr, objetivo):
#     """
#     Realiza una búsqueda binaria en un array ordenado para encontrar el índice del objetivo.
#
#     Parámetros:
#     - arr: Lista ordenada de elementos (ascendente o descendente).
#     - objetivo: Elemento a buscar en la lista.
#
#     Retorna:
#     - Índice del objetivo si se encuentra.
#     - -1 si el objetivo no está en la lista.
#     """
#     izquierdo = 0
#     derecho = len(arr) - 1
#
#     while izquierdo <= derecho:
#         medio = (izquierdo + derecho) // 2  # Índice del elemento medio
#
#         if arr[medio] == objetivo:
#             return medio  # Objetivo encontrado
#         elif arr[medio] < objetivo:
#             izquierdo = medio + 1  # Buscar en la mitad derecha
#         else:
#             derecho = medio - 1  # Buscar en la mitad izquierda
#
#     return -1  # Objetivo no encontrado
#
# # Ejemplo de uso:
# if __name__ == "__main__":
#     lista_ordenada = [1, 3, 5, 7, 9, 11, 13, 15]
#     objetivo = 7
#
#     resultado = busqueda_binaria(lista_ordenada, objetivo)
#
#     if resultado != -1:
#         print(f"El elemento {objetivo} está en el índice {resultado}.")
#     else:
#         print(f"El elemento {objetivo} no está en la lista.")
# ```
#
# ### Explicación:
# 1. **Inicialización**:
#    - `izquierdo` y `derecho` definen el rango de búsqueda inicial (todo el array).
# 2. **Bucle `while`**:
#    - Calcula el índice del elemento medio (`medio`).
#    - Si el elemento medio es igual al objetivo, devuelve su índice.
#    - Si el objetivo es mayor, ajusta `izquierdo` para buscar en la mitad derecha.
#    - Si el objetivo es menor, ajusta `derecho` para buscar en la mitad izquierda.
# 3. **Retorno**:
#    - Si el bucle termina sin encontrar el objetivo, devuelve `-1`.
#
# ### Versión recursiva (opcional):
# Si prefieres una implementación recursiva:
# ```python
# def busqueda_binaria_recursiva(arr, objetivo, izquierdo=0, derecho=None):
#     if derecho is None:
#         derecho = len(arr) - 1
#
#     if izquierdo > derecho:
#         return -1
#
#     medio = (izquierdo + derecho) // 2
#
#     if arr[medio] == objetivo:
#         return medio
#     elif arr[medio] < objetivo:
#         return busqueda_binaria_recursiva(arr, objetivo, medio + 1, derecho)
#     else:
#         return busqueda_binaria_recursiva(arr, objetivo, izquierdo, medio - 1)
# ```
#
# ### Notas importantes:
# - **El array debe estar ordenado** (ascendente o descendente). Si está desordenado, la búsqueda binaria no funcionará correctamente.
# - Para arrays en orden descendente, modifica las condiciones `arr[medio] < objetivo` y `arr[medio] > objetivo` según corresponda.
#
# ¿Necesitas alguna adaptación o explicación adicional? 😊

# %% [markdown]
# ## Gemini

# %%
from google import genai
import os

os.environ["GEMINI_API_KEY"] = "<token>"
client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash", contents="Escribe una función en Python para búsqueda binaria para un array ordenado.",
    config={
        "system_instruction": "Eres un gran programador, experto en Python. Usar emojis en los comentarios para ser friendly.",
    }
)
print(response.text)

# %% [markdown]
# # OpenAI API

# %%
from openai import OpenAI

client = OpenAI(api_key="TOKEN")

response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Explain quicksort and give Python code."}
    ],
    temperature=0.2,
    max_tokens=2000
)

print(response.choices[0].message.content)

# %% [markdown]
# # Ejercicio
#
# Haz un programa que reciba como entrada una petición de un usuario en lenguaje natural de generación de código en Python (ejemplo, "dame un programa que ordene un array") y devuelva un programa en Python que cumpla esa función. Para ello, haz lo siguiente:
# 1. Crea un prompt adecuado y mete en él la petición del usuario.
# 2. Llama a alguna API (Ollama, Gemini, etc.) para generar el código.
# 3. Extrae el código con regex.
# 4. Ejecuta el código generado. Si da errores, vuelve a llamar al LLM con el feedback. Para ejecutar código en Python, puedes usar la función `exec`.
# ```python
# import traceback
#
# codigo_generado = "1/0"
# try:
#     exec(codigo_generado)
# except Exception as e:
#     error_completo = traceback.format_exc()
#     print(error_completo)
# ```
# 5. Repite el proceso hasta que el código se ejecute sin errores con un máximo de 5 iteraciones.

# %%
#Ejercicio propuesto

#Partes necesarias

#1. Pedir la información al usuario

input_user = input("¿Qué program en python quieres que haga?: ")

#Llamar a ollama. OJO, el input tiene que estar en el mensaje. Es decir, no es un mensaje fijo
# !pip install ollama
from ollama import Client

API_KEY = "64596f8798a148c1a6d230810171b445.9O8NWylmgIsOA98Ajsf6Qry5"

client = Client(
    host="https://ollama.com",
    headers={'Authorization': 'Bearer ' + API_KEY}
)

messages = [
  {"role": "system", "content": "Eres un asistente maravilloso de programación."},
  {"role": "user", "content": "Genera un programa en Python que haga lo siguiente: {input_user}"}
]

response = client.chat('ministral-3:14b-cloud', messages=messages, options={"temperature": 0.3})
print(response['message']['content'])

#Ahora extraemos el texto con regex
import re
import traceback

"""

#Ejecutamos y comprobamos si funciona:

try:
    exec(message)
except Exception as e:
    error = traceback.format_exc()
"""
# Out:
# ¿Qué program en python quieres que haga?: uno que sume 2 números
# Requirement already satisfied: ollama in /usr/local/lib/python3.12/dist-packages (0.6.1)
# Requirement already satisfied: httpx>=0.27 in /usr/local/lib/python3.12/dist-packages (from ollama) (0.28.1)
# Requirement already satisfied: pydantic>=2.9 in /usr/local/lib/python3.12/dist-packages (from ollama) (2.12.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27->ollama) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27->ollama) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27->ollama) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27->ollama) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.27->ollama) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9->ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9->ollama) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9->ollama) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9->ollama) (0.4.2)
# ¡Claro! Para poder ayudarte a generar un programa en Python que cumpla con lo que necesitas, dime exactamente qué es lo que quieres que haga el programa. Por ejemplo:
#
# - ¿Quieres que **procesar una entrada del usuario** (como un nombre, número, texto, etc.)?
# - ¿Que **realice cálculos matemáticos** (sumas, multiplicaciones, raíces, etc.)?
# - ¿Que **manipule archivos** (leer/guardar datos en un archivo de texto, CSV, JSON, etc.)?
# - ¿Que **interactúe con APIs** (como obtener datos del clima, noticias, etc.)?
# - ¿Que **genere gráficos o visualizaciones** (con `matplotlib`, `seaborn`, etc.)?
# - ¿Que **juegue un juego simple** (como adivinar un número, piedra-papel-tijera, etc.)?
# - ¿Que **organice o filtre datos** (como una lista de compras, tareas, etc.)?
# - ¿Que **automatice tareas** (como enviar correos, mover archivos, etc.)?
# - ¿O algo completamente diferente?
#
# ### Ejemplo de lo que podrías pedir:
# *"Quiero un programa que pida al usuario su nombre y edad, y luego muestre un mensaje personalizado como 'Hola [nombre], tienes [edad] años. ¡Eres genial!'"*
#
# ---
# ### **Ejemplo rápido de código (según tu posible solicitud):**
# Si quieres algo como lo del ejemplo anterior, aquí tienes el código:
#
# ```python
# # Programa que saluda al usuario con su nombre y edad
# nombre = input("¿Cómo te llamas? ")
# edad = input("¿Cuántos años tienes? ")
#
# print(f"Hola {nombre}, tienes {edad} años. ¡Eres genial!")
# ```
#
# ---
# **Dime exactamente qué necesitas** y te generaré un programa funcional, con explicaciones y mejoras si lo deseas. ¡Estoy aquí para ayudarte! 😊
#
# *(Si tu solicitud es muy específica, como trabajar con una API o un algoritmo complejo, también puedo adaptarme).*
# '\n\n#Ejecutamos y comprobamos si funciona:\n\ntry:\n    exec(message)\nexcept Exception as e:\n    error = traceback.format_exc()\n'
