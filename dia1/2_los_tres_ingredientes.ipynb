# %% [markdown]
# # Librerías

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from sklearn.datasets import load_iris
# !pip install torchviz
from torchviz import make_dot
# Out:
# Requirement already satisfied: torchviz in /usr/local/lib/python3.12/dist-packages (0.0.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from torchviz) (2.10.0+cpu)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (from torchviz) (0.21)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (3.24.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (2025.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->torchviz) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->torchviz) (3.0.3)

# %% [markdown]
# # Iris dataset

# %%
# En PyTorch, los datasets deben heredar de torch.utils.data.Dataset
class IrisDataset(Dataset):
    # Inicializamos el dataset cargando los datos
    def __init__(self):
        data = load_iris()
        self.X = torch.tensor(
            data.data, dtype=torch.float32
        )  # (150, 4)
        self.y = torch.tensor(
            data.target, dtype=torch.long
        )  # (150,)

    # PyTorch necesita saber el tamaño del dataset
    def __len__(self):
        return self.X.shape[0]

    # PyTorch necesita poder indexar el dataset
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# %%
full_iris_dataset = IrisDataset()

# %%
# ejemplos de muestras
for i in [1, 50, 100]:
    x, y = full_iris_dataset[i]
    print(f"Muestra {i}: x = {x}, y = {y}")
# Out:
# Muestra 1: x = tensor([4.9000, 3.0000, 1.4000, 0.2000]), y = 0
# Muestra 50: x = tensor([7.0000, 3.2000, 4.7000, 1.4000]), y = 1
# Muestra 100: x = tensor([6.3000, 3.3000, 6.0000, 2.5000]), y = 2

# %%
len(full_iris_dataset)
# Out:
# 150

# %% [markdown]
# # Definición de la red

# %%
class IrisRed(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(4, 3)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        h = self.fc1(x)   # (B, 3)
        return h

# el softmax no se suele incluir en el modelo porque
# 1) la función de pérdida CrossEntropyLoss ya lo incluye
# 2) y porque en inferencia se suele usar argmax (selección de la clase con mayor puntuación)

# %% [markdown]
# # Grafo computacional

# %%
# Instanciamos el modelo y el loss
# En PyTorch, el loss y el modelo suelen ser instanciados por separado
model = IrisRed()
criterion = nn.CrossEntropyLoss()

# Input dummy (batch size = 5)
x = torch.randn(5, 4, requires_grad=False)

# Forward
y = model(x)
# Loss
target = torch.tensor([1, 0, 2, 1, 2])  # clase verdadera
loss = criterion(y, target)


# Crear grafo computacional
dot = make_dot(loss, params=dict(model.named_parameters()))

# Mostrar o guardar
dot

# %% [markdown]
# # Stochastic Gradient Descent, dividr en batches

# %%
# esta función devuelve un iterador sobre batches
dataloader = DataLoader(full_iris_dataset, batch_size=16, shuffle=True)
# por otro lado, la red se ha definido para procesar batches de datos

# %% [markdown]
# # Juntamos los tres ingredientes

# %%
# instanciar modelo, loss y optimizador
# si se dispone de GPU, mover el modelo a GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# la red se inicializa a pesos aleatorios cada vez que se instancia
model = IrisRed().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-2)

# %%
num_epochs = 100
# durante un número de epochs
for epoch in range(1, num_epochs + 1):
    # poner el modelo en modo entrenamiento
    model.train()
    # para llevar la cuenta del loss
    running_loss = 0.0
    n_seen = 0
    for xB, yB in dataloader:
        xB, yB = xB.to(device), yB.to(device)
        optimizer.zero_grad()      # reset gradientes
        logits = model(xB)         # forward
        loss = criterion(logits, yB)
        loss.backward()            # backward
        optimizer.step()           # update
        running_loss += loss.item() * xB.size(0) # para llevar la cuenta del loss
        n_seen += xB.size(0)           # para llevar la cuenta del loss
    epoch_loss = running_loss / n_seen # loss medio en la epoch
    print(f"Epoch {epoch:03d} | train_loss = {epoch_loss:.4f}") # reportamos el loss
# Out:
# Epoch 001 | train_loss = 1.0590
# Epoch 002 | train_loss = 0.6806
# Epoch 003 | train_loss = 0.6783
# Epoch 004 | train_loss = 0.6517
# Epoch 005 | train_loss = 0.6475
# Epoch 006 | train_loss = 0.6343
# Epoch 007 | train_loss = 0.6297
# Epoch 008 | train_loss = 0.6215
# Epoch 009 | train_loss = 0.6022
# Epoch 010 | train_loss = 0.5996
# Epoch 011 | train_loss = 0.5905
# Epoch 012 | train_loss = 0.5838
# Epoch 013 | train_loss = 0.5702
# Epoch 014 | train_loss = 0.5725
# Epoch 015 | train_loss = 0.5658
# Epoch 016 | train_loss = 0.5564
# Epoch 017 | train_loss = 0.5519
# Epoch 018 | train_loss = 0.5462
# Epoch 019 | train_loss = 0.5396
# Epoch 020 | train_loss = 0.5373
# Epoch 021 | train_loss = 0.5310
# Epoch 022 | train_loss = 0.5263
# Epoch 023 | train_loss = 0.5206
# Epoch 024 | train_loss = 0.5154
# Epoch 025 | train_loss = 0.5187
# Epoch 026 | train_loss = 0.5088
# Epoch 027 | train_loss = 0.5026
# Epoch 028 | train_loss = 0.5110
# Epoch 029 | train_loss = 0.4998
# Epoch 030 | train_loss = 0.4935
# Epoch 031 | train_loss = 0.4933
# Epoch 032 | train_loss = 0.4874
# Epoch 033 | train_loss = 0.4824
# Epoch 034 | train_loss = 0.4799
# Epoch 035 | train_loss = 0.4823
# Epoch 036 | train_loss = 0.4763
# Epoch 037 | train_loss = 0.4800
# Epoch 038 | train_loss = 0.4703
# Epoch 039 | train_loss = 0.4767
# Epoch 040 | train_loss = 0.4659
# Epoch 041 | train_loss = 0.4650
# Epoch 042 | train_loss = 0.4600
# Epoch 043 | train_loss = 0.4563
# Epoch 044 | train_loss = 0.4570
# Epoch 045 | train_loss = 0.4493
# Epoch 046 | train_loss = 0.4525
# Epoch 047 | train_loss = 0.4469
# Epoch 048 | train_loss = 0.4450
# Epoch 049 | train_loss = 0.4420
# Epoch 050 | train_loss = 0.4423
# Epoch 051 | train_loss = 0.4357
# Epoch 052 | train_loss = 0.4332
# Epoch 053 | train_loss = 0.4311
# Epoch 054 | train_loss = 0.4394
# Epoch 055 | train_loss = 0.4283
# Epoch 056 | train_loss = 0.4276
# Epoch 057 | train_loss = 0.4233
# Epoch 058 | train_loss = 0.4191
# Epoch 059 | train_loss = 0.4181
# Epoch 060 | train_loss = 0.4179
# Epoch 061 | train_loss = 0.4184
# Epoch 062 | train_loss = 0.4153
# Epoch 063 | train_loss = 0.4162
# Epoch 064 | train_loss = 0.4115
# Epoch 065 | train_loss = 0.4118
# Epoch 066 | train_loss = 0.4103
# Epoch 067 | train_loss = 0.4056
# Epoch 068 | train_loss = 0.4032
# Epoch 069 | train_loss = 0.4030
# Epoch 070 | train_loss = 0.4027
# Epoch 071 | train_loss = 0.3999
# Epoch 072 | train_loss = 0.3979
# Epoch 073 | train_loss = 0.3991
# Epoch 074 | train_loss = 0.3938
# Epoch 075 | train_loss = 0.3926
# Epoch 076 | train_loss = 0.3919
# Epoch 077 | train_loss = 0.3928
# Epoch 078 | train_loss = 0.3859
# Epoch 079 | train_loss = 0.3859
# Epoch 080 | train_loss = 0.3836
# Epoch 081 | train_loss = 0.3821
# Epoch 082 | train_loss = 0.3798
# Epoch 083 | train_loss = 0.3808
# Epoch 084 | train_loss = 0.3790
# Epoch 085 | train_loss = 0.3768
# Epoch 086 | train_loss = 0.3741
# Epoch 087 | train_loss = 0.3751
# Epoch 088 | train_loss = 0.3706
# Epoch 089 | train_loss = 0.3691
# Epoch 090 | train_loss = 0.3724
# Epoch 091 | train_loss = 0.3708
# Epoch 092 | train_loss = 0.3664
# Epoch 093 | train_loss = 0.3675
# Epoch 094 | train_loss = 0.3648
# Epoch 095 | train_loss = 0.3651
# Epoch 096 | train_loss = 0.3607
# Epoch 097 | train_loss = 0.3625
# Epoch 098 | train_loss = 0.3579
# Epoch 099 | train_loss = 0.3585
# Epoch 100 | train_loss = 0.3574

# %% [markdown]
# # Ejercicio
#
# Divide el dataset en train y test, y entrena el modelo durante 100 epochs. Evalúa el accuracy en el conjunto de test.
# - `torch.utils.data.random_split`
# - `torch.argmax` con el parámetro `dim` (indica la dimensión a reducir). `dim` es equivalente a `axis` en NumPy. Seguntamente tengáis que usar `dim=1` para reducir la dimensión de las clases.
#
# Recuerda poner el modelo en modo evaluación con `model.eval()` cuando evalúes en el conjunto de test.

# %%
# Ejercicio

#Creamos nuestro dataset

dataset = IrisDataset()

import torch

#DIVIDIMOS EL DATASET

train_size = int(0.5 * len(dataset))
test_size = len(dataset) - train_size

train_dataset, test_dataset = torch.utils.data.random_split(
    dataset,
    [train_size, test_size]
)

# INSTANCIAMOS EL MODELO
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# la red se inicializa a pesos aleatorios cada vez que se instancia
model = IrisRed().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-2)
#ENTRENAMOS EL DATASET

num_epochs = 100
# durante un número de epochs
for epoch in range(1, num_epochs + 1):
    # poner el modelo en modo entrenamiento
    model.train()
    # para llevar la cuenta del loss
    running_loss = 0.0
    n_seen = 0
    for xB, yB in dataloader:
        xB, yB = xB.to(device), yB.to(device)
        optimizer.zero_grad()      # reset gradientes
        logits = model(xB)         # forward
        loss = criterion(logits, yB)
        loss.backward()            # backward
        optimizer.step()           # update
        running_loss += loss.item() * xB.size(0) # para llevar la cuenta del loss
        n_seen += xB.size(0)           # para llevar la cuenta del loss
    epoch_loss = running_loss / n_seen # loss medio en la epoch
    print(f"Epoch {epoch:03d} | train_loss = {epoch_loss:.4f}") # reportamos el loss"""
# Out:
# Epoch 001 | train_loss = 0.2712
# Epoch 002 | train_loss = 0.2715
# Epoch 003 | train_loss = 0.2693
# Epoch 004 | train_loss = 0.2704
# Epoch 005 | train_loss = 0.2675
# Epoch 006 | train_loss = 0.2681
# Epoch 007 | train_loss = 0.2662
# Epoch 008 | train_loss = 0.2667
# Epoch 009 | train_loss = 0.2664
# Epoch 010 | train_loss = 0.2660
# Epoch 011 | train_loss = 0.2667
# Epoch 012 | train_loss = 0.2656
# Epoch 013 | train_loss = 0.2639
# Epoch 014 | train_loss = 0.2622
# Epoch 015 | train_loss = 0.2625
# Epoch 016 | train_loss = 0.2624
# Epoch 017 | train_loss = 0.2636
# Epoch 018 | train_loss = 0.2609
# Epoch 019 | train_loss = 0.2598
# Epoch 020 | train_loss = 0.2604
# Epoch 021 | train_loss = 0.2593
# Epoch 022 | train_loss = 0.2626
# Epoch 023 | train_loss = 0.2590
# Epoch 024 | train_loss = 0.2564
# Epoch 025 | train_loss = 0.2574
# Epoch 026 | train_loss = 0.2578
# Epoch 027 | train_loss = 0.2569
# Epoch 028 | train_loss = 0.2574
# Epoch 029 | train_loss = 0.2557
# Epoch 030 | train_loss = 0.2547
# Epoch 031 | train_loss = 0.2524
# Epoch 032 | train_loss = 0.2584
# Epoch 033 | train_loss = 0.2551
# Epoch 034 | train_loss = 0.2523
# Epoch 035 | train_loss = 0.2513
# Epoch 036 | train_loss = 0.2522
# Epoch 037 | train_loss = 0.2524
# Epoch 038 | train_loss = 0.2497
# Epoch 039 | train_loss = 0.2506
# Epoch 040 | train_loss = 0.2484
# Epoch 041 | train_loss = 0.2491
# Epoch 042 | train_loss = 0.2491
# Epoch 043 | train_loss = 0.2474
# Epoch 044 | train_loss = 0.2466
# Epoch 045 | train_loss = 0.2477
# Epoch 046 | train_loss = 0.2459
# Epoch 047 | train_loss = 0.2470
# Epoch 048 | train_loss = 0.2468
# Epoch 049 | train_loss = 0.2482
# Epoch 050 | train_loss = 0.2466
# Epoch 051 | train_loss = 0.2445
# Epoch 052 | train_loss = 0.2443
# Epoch 053 | train_loss = 0.2437
# Epoch 054 | train_loss = 0.2442
# Epoch 055 | train_loss = 0.2430
# Epoch 056 | train_loss = 0.2451
# Epoch 057 | train_loss = 0.2441
# Epoch 058 | train_loss = 0.2415
# Epoch 059 | train_loss = 0.2416
# Epoch 060 | train_loss = 0.2413
# Epoch 061 | train_loss = 0.2420
# Epoch 062 | train_loss = 0.2394
# Epoch 063 | train_loss = 0.2391
# Epoch 064 | train_loss = 0.2391
# Epoch 065 | train_loss = 0.2384
# Epoch 066 | train_loss = 0.2383
# Epoch 067 | train_loss = 0.2388
# Epoch 068 | train_loss = 0.2378
# Epoch 069 | train_loss = 0.2360
# Epoch 070 | train_loss = 0.2362
# Epoch 071 | train_loss = 0.2381
# Epoch 072 | train_loss = 0.2353
# Epoch 073 | train_loss = 0.2357
# Epoch 074 | train_loss = 0.2338
# Epoch 075 | train_loss = 0.2331
# Epoch 076 | train_loss = 0.2345
# Epoch 077 | train_loss = 0.2361
# Epoch 078 | train_loss = 0.2334
# Epoch 079 | train_loss = 0.2320
# Epoch 080 | train_loss = 0.2327
# Epoch 081 | train_loss = 0.2314
# Epoch 082 | train_loss = 0.2323
# Epoch 083 | train_loss = 0.2320
# Epoch 084 | train_loss = 0.2346
# Epoch 085 | train_loss = 0.2329
# Epoch 086 | train_loss = 0.2291
# Epoch 087 | train_loss = 0.2300
# Epoch 088 | train_loss = 0.2278
# Epoch 089 | train_loss = 0.2294
# Epoch 090 | train_loss = 0.2294
# Epoch 091 | train_loss = 0.2278
# Epoch 092 | train_loss = 0.2285
# Epoch 093 | train_loss = 0.2285
# Epoch 094 | train_loss = 0.2283
# Epoch 095 | train_loss = 0.2287
# Epoch 096 | train_loss = 0.2260
# Epoch 097 | train_loss = 0.2263
# Epoch 098 | train_loss = 0.2253
# Epoch 099 | train_loss = 0.2259
# Epoch 100 | train_loss = 0.2258
